# %% [markdown]
# # Environment Setting

# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
from dateutil import parser
import time

# %% [markdown]
# note:
# 1. food type feature
# 2. Seated via Yelp Reservations
# 3. update review
# 4. helpful, oh no, love it ...

# %% [markdown]
# # Restaurant List

# %%
def get_availability(tag):
    if tag:
        checkmark = tag.find('span', {'class': 'icon--16-checkmark-v2'})
        closemark = tag.find('span', {'class': 'icon--16-close-v2'})
        if checkmark:
            return "true"
        elif closemark:
            return "false"
    return "n/a"

# %% [markdown]
# ## First Page Trial

# %%
import requests
from bs4 import BeautifulSoup
import re

# URL of the Yelp page to scrape
url = "https://www.yelp.com/search?find_desc=Restaurants&find_loc=New+York%2C+NY%2C+United+States&sortby=review_count"
city = 'New York'
# Send a GET request to the URL
response = requests.get(url)


# Check if the request was successful
if response.status_code == 200:
    info = pd.DataFrame(columns=['Name','Link', 'Label', 'Score', 'Review Amount','Outdoor seating Available','Delivery Available','Takeout Available','Price Range'])
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the container that holds the restaurant information
    restaurants = soup.find_all('div', class_='y-css-1he6azc')
    restaurant_data = []
    # Loop through each restaurant and extract the information
    for restaurant in restaurants:
      info_tag = restaurant.find('div', class_= 'y-css-cxcdjj')

      # Extract the restaurant's name
      name_tag = info_tag.find('a', class_='y-css-12ly5yx')
      name = name_tag.get_text() if name_tag else 'N/A'
      link = info_tag.find('a')['href']

      # Extract the restaurant's ranking (if available)
      # ranking_tag = info_tag.find('h3', class_='y-css-hcgwj4')
      # ranking_text = ranking_tag.get_text() if ranking_tag else 'N/A'
      # ranking_match = re.search(r'\d+', ranking_text)
      # ranking = ranking_match.group() if ranking_match else 'N/A'

      # Extract the labels/tags (e.g., cuisine type)
      labels_tags = restaurant.find_all('span', class_='y-css-1cn4gbs')
      labels = ', '.join([label.get_text() for label in labels_tags]) if labels_tags else 'N/A'

      reputation_section = restaurant.find('div', class_='y-css-ohs7lg')
      score_tag = restaurant.find('span', class_='y-css-jf9frv')
      score = score_tag.get_text() if score_tag else 'N/A'
      review_tag = restaurant.find_all('span',class_='y-css-wfbtsu')[0]
      review_amt = review_tag.get_text() if review_tag else 'N/A'


      price_range_tag = restaurant.find('span',class_='y-css-mfup3c')
      price_range = price_range_tag.get_text() if price_range_tag else 'N/A'

      location_tag = restaurant.find('div',class_='y-css-1lvo3zq')
      location_name = location_tag.find('span',class_='y-css-wfbtsu')
      location = location_name.get_text() if location_name else 'N/A'

      # Check for outdoor seating availability
      outdoor_seating = get_availability(restaurant.find('div', {'aria-label': ['Outdoor seating Available', 'Outdoor seating Not Available']}))
      delivery_available = get_availability(restaurant.find('div', {'aria-label': ['Delivery Available', 'Delivery Not Available']}))
      takeout_available = get_availability(restaurant.find('div', {'aria-label': ['Takeout Available', 'Takeout Not Available']}))

      restaurant_data.append({
        'Name': name,
        'Link': link,
        #'Ranking': ranking,
        'Location': location,
        'Label': labels,
        'Score': score,
        'Review Amount': review_amt,
        'Outdoor seating Available': outdoor_seating,
        'Delivery Available': delivery_available,
        'Takeout Available': takeout_available,
        'Price Range': price_range
        })
    df = pd.DataFrame(restaurant_data)

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

# %% [markdown]
# ## City List: need change to a loop for restaurant list capturing

# %%
nyc = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=New+York%2C+NY%2C+United+States'
LA = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Los+Angeles%2C+CA%2C+United+States'
Chicago = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Chicago%2C+IL%2C+United+States'
Dallas = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Dallas%2C+TX%2C+United+States'
Huston = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Huston%2C+ID%2C+United+States'
WashingtonDC = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Washington%2C+DC%2C+United+States'

# %% [markdown]
# ## Iterations: 24 pages

# %%
# Initialize the DataFrame
info = pd.DataFrame(columns=['Name','Ranking', 'Labels', 'Score', 'Review', 'Link',
                             'Outdoor seating Available', 'Delivery Available', 'Takeout Available'])

# Loop through the pages
for i in range(0, 240, 10):
    # URL of the Yelp page to scrape
    url = f"https://www.yelp.com/search?find_desc=Restaurants&find_loc=Huston%2C+ID%2C+United+States&sortby=review_count&start={i}"

    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the container that holds the restaurant information
        restaurants = soup.find_all('div', class_='y-css-1he6azc')
        restaurant_data = []

        # Loop through each restaurant and extract the information
        for restaurant in restaurants:
            info_tag = restaurant.find('div', class_='y-css-1uij873')

            # Extract the restaurant's name
            name_tag = info_tag.find('a', class_='y-css-12ly5yx')
            name = name_tag.get_text() if name_tag else 'N/A'
            link = info_tag.find('a')['href']

            # Extract the restaurant's ranking (if available)
            ranking_tag = info_tag.find('h3', class_='y-css-hcgwj4')
            ranking_text = ranking_tag.get_text() if ranking_tag else 'N/A'
            ranking_match = re.search(r'\d+', ranking_text)
            ranking = ranking_match.group() if ranking_match else 'N/A'

            # Extract the labels/tags (e.g., cuisine type)
            labels_tags = restaurant.find_all('span', class_='y-css-1cn4gbs')
            labels = ', '.join([label.get_text() for label in labels_tags]) if labels_tags else 'N/A'

            #reputation_section = restaurant.find('div', class_='y-css-ohs7lg')
            score_tag = restaurant.find('span', class_='y-css-jf9frv')
            score = score_tag.get_text() if score_tag else 'N/A'
            review_tag = restaurant.find_all('span', class_='y-css-wfbtsu')[0]
            review_amt = review_tag.get_text() if review_tag else 'N/A'

            # Extract availability features
            outdoor_seating = get_availability(restaurant.find('div', {'aria-label': ['Outdoor seating Available', 'Outdoor seating Not Available']}))
            delivery_available = get_availability(restaurant.find('div', {'aria-label': ['Delivery Available', 'Delivery Not Available']}))
            takeout_available = get_availability(restaurant.find('div', {'aria-label': ['Takeout Available', 'Takeout Not Available']}))

            restaurant_data.append({
                'Name': name,
                'Link': link,
                'Ranking': ranking,
                'Labels': labels,
                'Score': score,
                'Review': review_amt,
                'Outdoor seating Available': outdoor_seating,
                'Delivery Available': delivery_available,
                'Takeout Available': takeout_available
            })

        # Append the data to the DataFrame
        df_page = pd.DataFrame(restaurant_data)
        info = pd.concat([info, df_page], ignore_index=True)
        time.sleep(5)

    else:
      print(f"Failed to retrieve the page. Status code: {response.status_code}")
      break

# Display the DataFrame
# import ace_tools as tools; tools.display_dataframe_to_user(name="Restaurant Data with Availability", dataframe=info)
# print(info)
info
# Out:
# Failed to retrieve the page. Status code: 503
#                                    Name Ranking  \
# 0                              Brick 29       1
# 1                                 AMANO       2
# 2               Indian Creek Steakhouse       3
# 3                              Holy Cow       4
# 4                   JP Thailand Express       5
# 5                       Messenger Pizza       6
# 6                       The Egg Factory       7
# 7                  Mesa Tacos + Tequila       8
# 8                       Texas Roadhouse       9
# 9                     The Orchard House      10
# 10                      The Tower Grill      11
# 11                              Grit 2C      12
# 12                  Aloha Island Grille      13
# 13              Jalapenos Bar And Grill      14
# 14             Mr V’s Family Restaurant      15
# 15                          Sushi Sushi      16
# 16                   Buffalo Wild Wings      17
# 17                    Boise Fry Company      18
# 18  Red Robin Gourmet Burgers and Brews      19
# 19                 Hong Kong Restaurant      20
#
#                                        Labels Score          Review  \
# 0   New American, Comfort Food, Cocktail Bars  4.5   (1.2k reviews)
# 1                      Cocktail Bars, Mexican  4.3    (466 reviews)
# 2         Steakhouses, Seafood, Cocktail Bars  3.3    (426 reviews)
# 3                       New American, Burgers  4.2    (375 reviews)
# 4                                        Thai  4.6    (367 reviews)
# 5                           Pizza, Sandwiches  4.1    (366 reviews)
# 6                          Breakfast & Brunch  4.3    (260 reviews)
# 7    Tacos, Cocktail Bars, Breakfast & Brunch  4.2    (240 reviews)
# 8             Steakhouses, Barbeque, American  3.3    (229 reviews)
# 9                  Bakeries, Wine Bars, Cafes  4.2    (223 reviews)
# 10         American, Breakfast & Brunch, Bars  4.5    (217 reviews)
# 11                      Bars, American, Salad  4.3    (215 reviews)
# 12                                   Hawaiian  3.9    (213 reviews)
# 13                     Mexican, Cocktail Bars  3.8    (205 reviews)
# 14                           Diners, American  4.2    (198 reviews)
# 15                                 Sushi Bars  4.1    (194 reviews)
# 16       Chicken Wings, American, Sports Bars  1.9    (183 reviews)
# 17            Burgers, Fast Food, Gluten-Free  3.6    (183 reviews)
# 18                          Burgers, American  2.2    (169 reviews)
# 19                                  Cantonese  2.3    (165 reviews)
#
#                                                  Link  \
# 0                 /biz/brick-29-nampa?osq=Restaurants
# 1                 /biz/amano-caldwell?osq=Restaurants
# 2   /biz/indian-creek-steakhouse-caldwell?osq=Rest...
# 3                 /biz/holy-cow-nampa?osq=Restaurants
# 4    /biz/jp-thailand-express-nampa-2?osq=Restaurants
# 5          /biz/messenger-pizza-nampa?osq=Restaurants
# 6          /biz/the-egg-factory-nampa?osq=Restaurants
# 7       /biz/mesa-tacos-tequila-nampa?osq=Restaurants
# 8        /biz/texas-roadhouse-nampa-2?osq=Restaurants
# 9     /biz/the-orchard-house-caldwell?osq=Restaurants
# 10         /biz/the-tower-grill-nampa?osq=Restaurants
# 11            /biz/grit-2c-caldwell-2?osq=Restaurants
# 12     /biz/aloha-island-grille-nampa?osq=Restaurants
# 13  /biz/jalapenos-bar-and-grill-nampa-2?osq=Resta...
# 14  /biz/mr-vs-family-restaurant-caldwell?osq=Rest...
# 15           /biz/sushi-sushi-nampa-5?osq=Restaurants
# 16      /biz/buffalo-wild-wings-nampa?osq=Restaurants
# 17       /biz/boise-fry-company-nampa?osq=Restaurants
# 18  /biz/red-robin-gourmet-burgers-and-brews-nampa...
# 19  /biz/hong-kong-restaurant-nampa-2?osq=Restaurants
#
#    Outdoor seating Available Delivery Available Takeout Available
# 0                      false              false              true
# 1                        n/a                n/a              true
# 2                       true              false              true
# 3                        n/a              false              true
# 4                      false              false              true
# 5                       true               true              true
# 6                        n/a                n/a              true
# 7                       true              false              true
# 8                        n/a              false              true
# 9                       true              false              true
# 10                      true               true              true
# 11                     false              false              true
# 12                       n/a               true               n/a
# 13                      true              false              true
# 14                      true                n/a              true
# 15                     false               true              true
# 16                       n/a               true              true
# 17                      true               true              true
# 18                       n/a               true              true
# 19                       n/a               true              true

# %%
csv_file_name = f'Huston_list_240720.csv'
info.to_csv(csv_file_name, index=True)

# %%
origion_Dallas = pd.read_csv('Dallas_list_240720.csv')

# %%
origion_Dallas
# Out:
#      Unnamed: 0                        Name  Ranking  \
# 0             0                 Pecan Lodge        1
# 1             1            Maple Leaf Diner        2
# 2             2    Kenny’s Wood Fired Grill        3
# 3             3                     Ellen’s        4
# 4             4                  Ida Claire        5
# ..          ...                         ...      ...
# 235         235               Mercat Bistro      236
# 236         236  Fadi’s Mediterranean Grill      237
# 237         237                The Free Man      238
# 238         238  The Oceanaire Seafood Room      239
# 239         239                El Come Taco      240
#
#                                      Labels  Score          Review  \
# 0            Sandwiches, Barbeque, Southern    4.3  (6.6k reviews)
# 1      American, Breakfast & Brunch, Diners    4.5  (3.6k reviews)
# 2                   American, Seafood, Bars    4.6  (3.5k reviews)
# 3    Southern, American, Breakfast & Brunch    4.0  (3.5k reviews)
# 4              Southern, Breakfast & Brunch    4.2  (3.3k reviews)
# ..                                      ...    ...             ...
# 235       French, Breakfast & Brunch, Cafes    4.1   (620 reviews)
# 236    Greek, Middle Eastern, Mediterranean    3.9   (619 reviews)
# 237  Cajun/Creole, Sandwiches, Jazz & Blues    3.6   (619 reviews)
# 238                                 Seafood    3.7   (617 reviews)
# 239                                 Mexican    4.3   (612 reviews)
#
#                                                   Link  \
# 0            /biz/pecan-lodge-dallas-3?osq=Restaurants
# 1         /biz/maple-leaf-diner-dallas?osq=Restaurants
# 2    /biz/kennys-wood-fired-grill-dallas-2?osq=Rest...
# 3                 /biz/ellens-dallas-4?osq=Restaurants
# 4              /biz/ida-claire-addison?osq=Restaurants
# ..                                                 ...
# 235        /biz/mercat-bistro-dallas-2?osq=Restaurants
# 236  /biz/fadis-mediterranean-grill-dallas-2?osq=Re...
# 237           /biz/the-free-man-dallas?osq=Restaurants
# 238  /biz/the-oceanaire-seafood-room-dallas?osq=Res...
# 239           /biz/el-come-taco-dallas?osq=Restaurants
#
#     Outdoor seating Available Delivery Available Takeout Available
# 0                        True                NaN              True
# 1                        True               True              True
# 2                        True              False              True
# 3                        True               True              True
# 4                        True               True              True
# ..                        ...                ...               ...
# 235                      True              False              True
# 236                      True               True              True
# 237                      True               True              True
# 238                     False               True              True
# 239                       NaN               True              True
#
# [240 rows x 10 columns]

# %%
info.drop_duplicates().reindex()
# Out:
#                       Name Ranking                                 Labels  \
# 0            Bottega Louie       1  Italian, Desserts, Breakfast & Brunch
# 1    Porto’s Bakery & Cafe       2          Bakeries, Cafes, Custom Cakes
# 2    Porto’s Bakery & Cafe       3          Bakeries, Cafes, Custom Cakes
# 3                    Perch       4    Lounges, French, Breakfast & Brunch
# 4    Porto’s Bakery & Cafe       5          Bakeries, Custom Cakes, Cafes
# ..                     ...     ...                                    ...
# 235           Oh My Burger     236                                Burgers
# 236        Girl & The Goat     237                           New American
# 237          Running Goose     238             Gastropubs, Latin American
# 238       TAO Asian Bistro     239                  Asian Fusion, Lounges
# 239        Shamshiri Grill     240        Middle Eastern, Persian/Iranian
#
#     Score           Review                                               Link  \
# 0    4.1   (18.9k reviews)     /biz/bottega-louie-los-angeles?osq=Restaurants
# 1    4.5   (12.1k reviews)  /biz/portos-bakery-and-cafe-burbank?osq=Restau...
# 2    4.4   (11.3k reviews)  /biz/portos-bakery-and-cafe-glendale?osq=Resta...
# 3    4.1   (10.4k reviews)             /biz/perch-los-angeles?osq=Restaurants
# 4    4.4    (8.6k reviews)  /biz/portos-bakery-and-cafe-downey?osq=Restaur...
# ..    ...              ...                                                ...
# 235  4.2    (1.8k reviews)        /biz/oh-my-burger-gardena-3?osq=Restaurants
# 236  4.4    (1.8k reviews)  /biz/girl-and-the-goat-los-angeles-2?osq=Resta...
# 237  4.3    (1.8k reviews)     /biz/running-goose-los-angeles?osq=Restaurants
# 238  4.0    (1.8k reviews)  /biz/tao-asian-bistro-los-angeles-2?osq=Restau...
# 239  3.6    (1.8k reviews)   /biz/shamshiri-grill-los-angeles?osq=Restaurants
#
#     Outdoor seating Available Delivery Available Takeout Available
# 0                         n/a                n/a               n/a
# 1                         n/a                n/a               n/a
# 2                         n/a                n/a               n/a
# 3                         n/a                n/a               n/a
# 4                         n/a                n/a               n/a
# ..                        ...                ...               ...
# 235                      true               true              true
# 236                      true              false              true
# 237                      true               true              true
# 238                      true               true              true
# 239                       n/a               true              true
#
# [240 rows x 9 columns]

# %% [markdown]
# ### Restaurant Review

# %% [markdown]
# ##Review Content: One Restaurant Trial

# %%
url = 'https://www.yelp.com/biz/le-bernardin-new-york?osq=Restaurants&start=10&sort_by=date_desc'
response = requests.get(url)
content = response.content
soup = BeautifulSoup(content, 'html.parser')

review_section = soup.find('div', class_='y-css-1iy1dwt', id="reviews")
reviews = review_section.find_all('li', class_='y-css-1jp2syp')
count = 0
for review in reviews:
    count += 1
    print(f"#{count}. list:")
    print(review.text)

# %%
count
# Out:
# 0

# %%
url = 'https://www.yelp.com/biz/lovemama-new-york?osq=Restaurants&start=10&sort_by=date_desc'
response = requests.get(url)
content = response.content
soup = BeautifulSoup(content, 'html.parser')
review_section = soup.find('div', class_='y-css-1iy1dwt', id="reviews")
reviews = review_section.find_all('li', class_='y-css-1jp2syp')


for review in reviews:
    reaction_section = review.find('div', class_='y-css-o1wrcf')
    reaction_divs = reaction_section.find_all('div',class_='y-css-1b9tgy5')
    helpful = '0'
    thanks = '0'
    love_this = '0'
    oh_no = '0'

    for div in reaction_divs:
      label_tag = div.find('span', class_='y-css-16avcyn')
      count_tag = div.find('span', class_='y-css-q3ifzf')
      print(label_tag.get_text())
      print(count_tag.get_text())
      if label_tag and count_tag:
          if 'Helpful' in label_tag.get_text():
            helpful = count_tag.get_text()
          elif 'Thanks' in label_tag.get_text():
            thanks = count_tag.get_text()
          elif 'Love this' in label_tag.get_text():
            love_this = count_tag.get_text()
          elif 'Oh no' in label_tag.get_text():
            oh_no = count_tag.get_text()
          else:
            '0'
      else:
        print('no tags found')

# %% [markdown]
# ## Main Function

# %%
def check_claimed_status(html):
    soup = BeautifulSoup(html, 'html.parser')
    if soup.find('span', class_='icon--16-claim-filled-v2'):
        return 'Claimed'
    elif soup.find('a', href=True, text='Unclaimed'):
        return 'Unclaimed'
    else:
        return 'Status Unknown'

# %%
def restaurant_info(Link):
    url = f'https://www.yelp.com{Link}&sort_by=date_desc'
    response = requests.get(url)
    content = response.content
    soup = BeautifulSoup(content, 'html.parser')

    if response.status_code == 200:
      restaurant_list = []
      restaurant_tag = soup.find("h1", class_="y-css-olzveb")
      Restaurant = restaurant_tag.get_text() if restaurant_tag else 'N/A'

      location_tag = soup.find('p', class_='y-css-dg8xxd')
      location = location_tag.get_text() if location_tag else 'N/A'

      review_count_tag = soup.find('span', class_="y-css-loq5qn")
      review_count = review_count_tag.get_text() if review_count_tag else 'N/A'

      price_index_tag = soup.find_all('span', class_='y-css-33yfe')
      price_index = price_index_tag[-1].get_text() if price_index_tag else 'N/A'

      page_tag = soup.find('div', class_='y-css-xdax52')
      pages_total = page_tag.find('span', class_='y-css-wfbtsu')
      pages_total_number = pages_total.get_text() if pages_total else 'N/A'
      try:
        pages_total_number = pages_total_number.split('of ')[-1]
        if pages_total_number.isdigit():
          pages_total_number = int(pages_total_number)
        else:
          pages_total_number = 'Nan'
      except ValueError:
        pages_total_number = 'NA'

      # Find the div with the specific class
      # div_address = soup.find('div', class_='y-css-5qya4l')
      div_element = soup.find('div', class_="arrange__09f24__LDfbs gutter-1-5__09f24__vMtpw y-css-1iy1dwt")

      if div_element:
          # Extract the address and additional information
          address = soup.find('address')
          # address_street = []
          # district = []
          if address:
              address_street_tag = address.find('p',class_='y-css-r4s27p')
              address_street = address_street_tag.get_text() if address_street_tag else 'N/A'
              neighborhood_tag = address.find_all('p',class_='y-css-sauewc')
              if neighborhood_tag:
                if len(neighborhood_tag) >= 2:
                  district = neighborhood_tag[0].get_text() if neighborhood_tag else 'N/A'
                  state_zip = neighborhood_tag[1].get_text() if neighborhood_tag else 'N/A'
                else:
                  district = 'N/A'
                  state_zip = neighborhood_tag[0].get_text() if neighborhood_tag else 'N/A'
              else:
                print('no sauewc')
                district = 'N/A'
                zip_tag = address.find('p',class_='y-css-h9c2fl')
                state_zip = zip_tag.get_text() if zip_tag else 'N/A'
          else:
            print('didnt find address class')
          # Extract the other paragraphs with data-font-weight="semibold"

          semibold_paragraphs = div_element.find_all('p', class_='y-css-jf9frv') #, attrs={"data-font-weight": "semibold"}
          if semibold_paragraphs:
            # print(semibold_paragraphs)
            if len(semibold_paragraphs) >= 2:
              street_tag =  semibold_paragraphs[0]
              street_address = street_tag.get_text() if street_tag else 'N/A'
              block_tag = semibold_paragraphs[1]
              block = block_tag.get_text() if block_tag else 'N/A'
            else:
              street_address = 'N/A'
              block_tag = semibold_paragraphs[0]
              block = block_tag.get_text() if block_tag else 'N/A'
          else:
            print('district cannot be found')
            street_address = 'N/A'
            block = 'N/A'
      else:
          print("Cannot find location section.")

      # restaurant_list.append({
      #       'restaurant': Restaurant,
      #       'review count':review_count,
      #       'price index': price_index,
      #       'address':address_street,
      #       'district': district,
      #       'zip': state_zip,
      #       'street': street_address,
      #       'block':block})

      restaurant_info_series = pd.Series({
        'review count': review_count,
        'price index': price_index,
        'pages': pages_total_number,
        'address': address_street,
        'district': district,
        'zip': state_zip,
        'street': street_address,
        'block': block})
    else:
      print(f"Failed to retrieve the page. Status code: {response.status_code}")
    return restaurant_info_series

# %% [markdown]
# ### Test examples of restaurant info

# %%
Link = '/biz/daikokuya-los-angeles-7?osq=Restaurants'
df1 = restaurant_info(Link)
df1
# Out:
# review count           (9,665 reviews)
# price index                        $$
# pages                              965
# address                   327 E 1st St
# district                           N/A
# zip              Los Angeles, CA 90012
# street                             N/A
# block           Little Tokyo, Downtown
# dtype: object

# %%
Link = '/biz/l-and-b-spumoni-gardens-brooklyn?osq=Restaurants'
df2 = restaurant_info(Link)
df2
# Out:
#               restaurant     review count price index       address district  \
# 0  L & B Spumoni Gardens  (4,740 reviews)         $$   2725 86th St      N/A
#
#                   zip             street      block
# 0  Brooklyn, NY 11223  11th St & 10th St  Gravesend

# %%
Link = '/biz/beauty-and-essex-new-york-city?osq=Restau...'
df3 = restaurant_info(Link)
df3
# Out:
#        restaurant     review count price index       address district  \
# 0  Beauty & Essex  (3,933 reviews)        $$$   146 Essex St      N/A
#
#                        zip                     street            block
# 0  New York City, NY 10002  Stanton St & Rivington St  Lower East Side

# %% [markdown]
# ## Restaurant list

# %%
list_file_name = '945_restaurant_nyc.csv'
restaurant_list = pd.read_csv(list_file_name).drop_duplicates()
restaurant_list[20:40]
# Out:
#     Unnamed: 0                              Name  Ranking  \
# 20          20                Nom Wah Tea Parlor       21
# 21          21            Boucherie West Village       22
# 22          22                       Butcher Bar       23
# 23          23                          Freemans       24
# 24          24          Mad For Chicken Flushing       25
# 25          25         Ayza Wine & Chocolate Bar       26
# 26          26                       Dutch Freds       27
# 27          27                             Traif       28
# 28          28   Upstate Craft Beer & Oyster Bar       29
# 29          29                            Lucali       30
# 30          30                       Chart House       31
# 31          31               Mitsuwa Marketplace       32
# 32          32                            Per Se       33
# 33          33                     Locanda Verde       34
# 34          34                            Wo Hop       35
# 35          35                    Dim Sum Palace       36
# 36          36                       Five Leaves       37
# 37          37  Lillie’s Victorian Establishment       38
# 38          38                         La Sirene       39
# 39          39                Xi’an Famous Foods       40
#
#                                              Labels  Score          Review  \
# 20                                          Dim Sum    3.6  (2.4k reviews)
# 21               French, Cocktail Bars, Steakhouses    4.5  (2.4k reviews)
# 22                                Barbeque, Burgers    4.0  (2.3k reviews)
# 23            Breakfast & Brunch, Lounges, American    3.8  (2.2k reviews)
# 24                Korean, Chicken Wings, Gastropubs    4.1  (2.2k reviews)
# 25                Wine Bars, Desserts, New American    4.1  (2.1k reviews)
# 26  Cocktail Bars, New American, Breakfast & Brunch    4.5  (2.1k reviews)
# 27                 New American, Tapas/Small Plates    4.4  (2.1k reviews)
# 28                                          Seafood    4.4  (2.1k reviews)
# 29                                            Pizza    4.2  (2.1k reviews)
# 30      Seafood, Steakhouses, Venues & Event Spaces    4.0  (1.9k reviews)
# 31      Japanese, Sushi Bars, International Grocery    4.3  (1.9k reviews)
# 32                                           French    4.5  (1.9k reviews)
# 33       Italian, Cocktail Bars, Breakfast & Brunch    3.9  (1.9k reviews)
# 34                           Chinese, Noodles, Soup    3.8  (1.8k reviews)
# 35                               Dim Sum, Cantonese    4.1  (1.8k reviews)
# 36                 New American, Coffee & Tea, Bars    3.9  (1.8k reviews)
# 37                        Bars, Gastropubs, Burgers    3.9  (1.7k reviews)
# 38                        French, Wine Bars, Fondue    4.3  (1.7k reviews)
# 39                        Chinese, Burgers, Noodles    4.0  (1.7k reviews)
#
#                                                  Link  \
# 20   /biz/nom-wah-tea-parlor-new-york?osq=Restaurants
# 21  /biz/boucherie-west-village-new-york-3?osq=Res...
# 22         /biz/butcher-bar-astoria-2?osq=Restaurants
# 23           /biz/freemans-new-york-3?osq=Restaurants
# 24  /biz/mad-for-chicken-flushing-flushing-2?osq=R...
# 25  /biz/ayza-wine-and-chocolate-bar-new-york-6?os...
# 26        /biz/dutch-freds-new-york-2?osq=Restaurants
# 27                /biz/traif-brooklyn?osq=Restaurants
# 28  /biz/upstate-craft-beer-and-oyster-bar-new-yor...
# 29             /biz/lucali-brooklyn-3?osq=Restaurants
# 30         /biz/chart-house-weehawken?osq=Restaurants
# 31  /biz/mitsuwa-marketplace-edgewater-3?osq=Resta...
# 32               /biz/per-se-new-york?osq=Restaurants
# 33        /biz/locanda-verde-new-york?osq=Restaurants
# 34               /biz/wo-hop-new-york?osq=Restaurants
# 35     /biz/dim-sum-palace-new-york-8?osq=Restaurants
# 36        /biz/five-leaves-brooklyn-2?osq=Restaurants
# 37  /biz/lillies-victorian-establishment-new-york-...
# 38          /biz/la-sirene-new-york-4?osq=Restaurants
# 39  /biz/xian-famous-foods-new-york-39?osq=Restaur...
#
#    Outdoor seating Available Delivery Available Takeout Available
# 20                     False               True              True
# 21                      True               True              True
# 22                      True               True              True
# 23                      True               True              True
# 24                     False               True              True
# 25                       NaN               True              True
# 26                      True                NaN              True
# 27                      True               True              True
# 28                      True              False             False
# 29                      True               True              True
# 30                     False               True              True
# 31                       NaN                NaN              True
# 32                       NaN                NaN               NaN
# 33                      True               True              True
# 34                      True                NaN              True
# 35                      True               True              True
# 36                      True               True              True
# 37                       NaN               True              True
# 38                     False               True              True
# 39                     False              False              True

# %% [markdown]
# ## Combine restaurant list

# %%
import pandas as pd
import glob

# List all CSV files
csv_files = glob.glob('*.csv')

# Initialize an empty list to store DataFrames
dataframes = []

# Loop through each CSV file and read it into a DataFrame
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Concatenate all DataFrames
combined_df = pd.concat(dataframes, ignore_index=True)

# Drop duplicate rows
unique_df = combined_df.drop_duplicates()

# Save the resulting DataFrame to a new CSV file
unique_df.to_csv(f'{len(unique_df)}_restaurant_LA.csv', index=False)

# %%
unique_df = pd.read_csv('restaurant_LA_393_remove_overlap.csv')
unique_df
# Out:
#      Unnamed: 0                                      Name  \
# 0             0                             Bottega Louie
# 1             1                     Porto’s Bakery & Cafe
# 2             2                     Porto’s Bakery & Cafe
# 3             3                                Wurstküche
# 4             4                     Porto’s Bakery & Cafe
# ..          ...                                       ...
# 388         388               Marmalade Cafe - El Segundo
# 389         389                                Daisy Mint
# 390         390  Mama Hong’s Vietnamese Kitchen - Burbank
# 391         391                         CUT Beverly Hills
# 392         392                              Son of a Gun
#
#                                       Labels  Score           Review  \
# 0      Italian, Desserts, Breakfast & Brunch    4.1  (18.9k reviews)
# 1              Bakeries, Cafes, Custom Cakes    4.5  (12.1k reviews)
# 2              Bakeries, Cafes, Custom Cakes    4.4  (11.3k reviews)
# 3               Hot Dogs, German, Gastropubs    4.2   (9.1k reviews)
# 4              Bakeries, Custom Cakes, Cafes    4.4   (8.6k reviews)
# ..                                       ...    ...              ...
# 388  New American, Breakfast & Brunch, Cafes    3.8   (1.9k reviews)
# 389                       Thai, Asian Fusion    4.0   (1.9k reviews)
# 390                               Vietnamese    3.8   (1.9k reviews)
# 391                Steakhouses, New American    4.0   (1.8k reviews)
# 392                                  Seafood    3.8   (1.9k reviews)
#
#                                                   Link  \
# 0       /biz/bottega-louie-los-angeles?osq=Restaurants
# 1    /biz/portos-bakery-and-cafe-burbank?osq=Restau...
# 2    /biz/portos-bakery-and-cafe-glendale?osq=Resta...
# 3    /biz/wurstk%C3%BCche-los-angeles-2?osq=Restaur...
# 4    /biz/portos-bakery-and-cafe-downey?osq=Restaur...
# ..                                                 ...
# 388  /biz/marmalade-cafe-el-segundo-el-segundo-3?os...
# 389           /biz/daisy-mint-pasadena?osq=Restaurants
# 390  /biz/mama-hongs-vietnamese-kitchen-burbank-bur...
# 391  /biz/cut-beverly-hills-beverly-hills-3?osq=Res...
# 392      /biz/son-of-a-gun-los-angeles?osq=Restaurants
#
#     Outdoor seating Available Delivery Available Takeout Available
# 0                         NaN                NaN               NaN
# 1                         NaN                NaN               NaN
# 2                         NaN                NaN               NaN
# 3                         NaN                NaN               NaN
# 4                         NaN                NaN               NaN
# ..                        ...                ...               ...
# 388                      True               True              True
# 389                      True               True              True
# 390                     False               True              True
# 391                      True                NaN              True
# 392                      True               True              True
#
# [393 rows x 9 columns]

# %% [markdown]
# ## Adding restaurant info to df

# %%
columns_to_add = ['review count', 'price index', 'address', 'district', 'zip', 'street', 'block']
for column in columns_to_add:
    unique_df.loc[:, column] = None

# %%
def pages_number(Link):
    url = f'https://www.yelp.com{Link}&sort_by=date_desc'
    response = requests.get(url)
    content = response.content
    soup = BeautifulSoup(content, 'html.parser')
    if response.status_code == 200:
      div_element = soup.find('div', class_="y-css-1iy1dwt", id='reviews')
      page_tag = div_element.find('div', class_='y-css-xdax52')
      pages_total = page_tag.find('span', class_='y-css-wfbtsu')
      pages_total_number = pages_total.get_text() if pages_total else 'N/A'
      try:
        pages_total_number = pages_total_number.split('of ')[-1]
        # if pages_total_number.isdigit():
        #   pages_total_number = int(pages_total_number)
        # else:
        #   pages_total_number = 'Nan'
      except ValueError:
        pages_total_number = 'NA'

      restaurant_info_series = pd.Series({
        'pages': pages_total_number})
    else:
      print(f"Failed to retrieve the page. Status code: {response.status_code}")
    return restaurant_info_series

# %%
Link = '/biz/morrison-atwater-village-los-angeles?osq=...'
df4 = pages_number(Link)
df4
# Out:
# pages    800
# dtype: object

# %%
for index, row in unique_df.iloc[0:10].iterrows():
  # if row['pages'] == 'N/A':
    link = row["Link"]
    # Get the restaurant information
    res_info = restaurant_info(link)
    # Update the corresponding row in unique_df with the new data using .loc
    unique_df.loc[index, res_info.index] = res_info
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-254-f4c211fc2ca6> in <cell line: 1>()
#       3     link = row["Link"]
#       4     # Get the restaurant information
# ----> 5     res_info = restaurant_info(link)
#       6     # Update the corresponding row in unique_df with the new data using .loc
#       7     unique_df.loc[index, res_info.index] = res_info
#
# <ipython-input-141-2fb3f78ac783> in restaurant_info(Link)
#      20
#      21       page_tag = soup.find('div', class_='y-css-xdax52')
# ---> 22       pages_total = page_tag.find('span', class_='y-css-wfbtsu')
#      23       pages_total_number = pages_total.get_text() if pages_total else 'N/A'
#      24       try:
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
print(index)
# Out:
# 289

# %%
count = 0
for index, row in unique_df.iterrows():
  if row['pages'] == 'N/A':
    count += 1
print(count)
# Out:
# 38

# %%
unique_df
# Out:
#                                          Name  \
# 0                               Bottega Louie
# 1                       Porto’s Bakery & Cafe
# 2                       Porto’s Bakery & Cafe
# 3                                  Wurstküche
# 4                       Porto’s Bakery & Cafe
# ..                                        ...
# 388               Marmalade Cafe - El Segundo
# 389                                Daisy Mint
# 390  Mama Hong’s Vietnamese Kitchen - Burbank
# 391                         CUT Beverly Hills
# 392                              Son of a Gun
#
#                                       Labels  Score           Review  \
# 0      Italian, Desserts, Breakfast & Brunch    4.1  (18.9k reviews)
# 1              Bakeries, Cafes, Custom Cakes    4.5  (12.1k reviews)
# 2              Bakeries, Cafes, Custom Cakes    4.4  (11.3k reviews)
# 3               Hot Dogs, German, Gastropubs    4.2   (9.1k reviews)
# 4              Bakeries, Custom Cakes, Cafes    4.4   (8.6k reviews)
# ..                                       ...    ...              ...
# 388  New American, Breakfast & Brunch, Cafes    3.8   (1.9k reviews)
# 389                       Thai, Asian Fusion    4.0   (1.9k reviews)
# 390                               Vietnamese    3.8   (1.9k reviews)
# 391                Steakhouses, New American    4.0   (1.8k reviews)
# 392                                  Seafood    3.8   (1.9k reviews)
#
#                                                   Link  \
# 0       /biz/bottega-louie-los-angeles?osq=Restaurants
# 1    /biz/portos-bakery-and-cafe-burbank?osq=Restau...
# 2    /biz/portos-bakery-and-cafe-glendale?osq=Resta...
# 3    /biz/wurstk%C3%BCche-los-angeles-2?osq=Restaur...
# 4    /biz/portos-bakery-and-cafe-downey?osq=Restaur...
# ..                                                 ...
# 388  /biz/marmalade-cafe-el-segundo-el-segundo-3?os...
# 389           /biz/daisy-mint-pasadena?osq=Restaurants
# 390  /biz/mama-hongs-vietnamese-kitchen-burbank-bur...
# 391  /biz/cut-beverly-hills-beverly-hills-3?osq=Res...
# 392      /biz/son-of-a-gun-los-angeles?osq=Restaurants
#
#     Outdoor seating Available Delivery Available Takeout Available  \
# 0                         NaN                NaN               NaN
# 1                         NaN                NaN               NaN
# 2                         NaN                NaN               NaN
# 3                         NaN                NaN               NaN
# 4                         NaN                NaN               NaN
# ..                        ...                ...               ...
# 388                      True               True              True
# 389                      True               True              True
# 390                     False               True              True
# 391                      True                NaN              True
# 392                      True               True              True
#
#          review count price index                  address district  \
# 0    (18,920 reviews)         $$           700 S Grand Ave      N/A
# 1    (12,125 reviews)          $      3614 W Magnolia Blvd      N/A
# 2    (11,285 reviews)          $          315 N Brand Blvd      N/A
# 3     (9,068 reviews)         $$              800 E 3rd St      N/A
# 4     (8,661 reviews)          $       8233 Firestone Blvd      N/A
# ..                ...         ...                      ...      ...
# 388   (1,889 reviews)         $$              2014 Park Pl      N/A
# 389   (1,884 reviews)         $$      1218 E Colorado Blvd      N/A
# 390   (1,854 reviews)         $$   211 N San Fernando Blvd      N/A
# 391   (1,845 reviews)       $$$$        9500 Wilshire Blvd      N/A
# 392   (1,894 reviews)        $$$             8370 W 3rd St      N/A
#
#                          zip street                    block pages
# 0      Los Angeles, CA 90017    N/A                 Downtown  1888
# 1          Burbank, CA 91505    N/A                      N/A  1207
# 2         Glendale, CA 91203    N/A                      N/A  1125
# 3      Los Angeles, CA 90013    N/A  Arts District, Downtown   906
# 4           Downey, CA 90241    N/A                      N/A   859
# ..                       ...    ...                      ...   ...
# 388     El Segundo, CA 90245    N/A                      N/A   189
# 389       Pasadena, CA 91106    N/A                      N/A   189
# 390        Burbank, CA 91502    N/A                      N/A   186
# 391  Beverly Hills, CA 90212    N/A                      N/A   184
# 392    Los Angeles, CA 90048    N/A            Beverly Grove   190
#
# [393 rows x 16 columns]

# %%
unique_df.to_csv('LA_393_restaurant_list_393_completed.csv')

# %%
unique_df_114 = pd.read_csv('LA_393_restaurant_list_114.csv')
unique_df_114
# Out:
#      Unnamed: 0                   Name                                 Labels  \
# 0             0          Bottega Louie  Italian, Desserts, Breakfast & Brunch
# 1             1  Porto’s Bakery & Cafe          Bakeries, Cafes, Custom Cakes
# 2             2  Porto’s Bakery & Cafe          Bakeries, Cafes, Custom Cakes
# 3             3             Wurstküche           Hot Dogs, German, Gastropubs
# 4             4  Porto’s Bakery & Cafe          Bakeries, Custom Cakes, Cafes
# ..          ...                    ...                                    ...
# 109         109        Joan’s on Third              Breakfast & Brunch, Cafes
# 110         110                  Otium                           New American
# 111         111                  Bavel                         Middle Eastern
# 112         112           Sun Nong Dan                           Korean, Soup
# 113         113  Takami Sushi & Robata          Sushi Bars, Japanese, Seafood
#
#      Score           Review  \
# 0      4.1  (18.9k reviews)
# 1      4.5  (12.1k reviews)
# 2      4.4  (11.3k reviews)
# 3      4.2   (9.1k reviews)
# 4      4.4   (8.6k reviews)
# ..     ...              ...
# 109    4.0   (2.6k reviews)
# 110    4.0   (2.6k reviews)
# 111    4.4   (2.6k reviews)
# 112    4.3   (2.5k reviews)
# 113    3.8   (2.5k reviews)
#
#                                                   Link  \
# 0       /biz/bottega-louie-los-angeles?osq=Restaurants
# 1    /biz/portos-bakery-and-cafe-burbank?osq=Restau...
# 2    /biz/portos-bakery-and-cafe-glendale?osq=Resta...
# 3    /biz/wurstk%C3%BCche-los-angeles-2?osq=Restaur...
# 4    /biz/portos-bakery-and-cafe-downey?osq=Restaur...
# ..                                                 ...
# 109    /biz/joans-on-third-los-angeles?osq=Restaurants
# 110             /biz/otium-los-angeles?osq=Restaurants
# 111           /biz/bavel-los-angeles-3?osq=Restaurants
# 112    /biz/sun-nong-dan-los-angeles-4?osq=Restaurants
# 113  /biz/takami-sushi-and-robata-los-angeles-2?osq...
#
#     Outdoor seating Available Delivery Available Takeout Available  \
# 0                         NaN                NaN               NaN
# 1                         NaN                NaN               NaN
# 2                         NaN                NaN               NaN
# 3                         NaN                NaN               NaN
# 4                         NaN                NaN               NaN
# ..                        ...                ...               ...
# 109                      True               True              True
# 110                      True              False              True
# 111                     False              False              True
# 112                      True               True              True
# 113                      True               True              True
#
#          review count price index               address  district  \
# 0    (18,920 reviews)         $$        700 S Grand Ave       NaN
# 1    (12,125 reviews)          $   3614 W Magnolia Blvd       NaN
# 2    (11,285 reviews)          $       315 N Brand Blvd       NaN
# 3     (9,068 reviews)         $$           800 E 3rd St       NaN
# 4     (8,661 reviews)          $    8233 Firestone Blvd       NaN
# ..                ...         ...                   ...       ...
# 109   (2,613 reviews)         $$          8350 W 3rd St       NaN
# 110   (2,573 reviews)        $$$          222 S Hope St       NaN
# 111   (2,575 reviews)        $$$           500 Mateo St       NaN
# 112   (2,557 reviews)        $$$          3470 W 6th St     Ste 7
# 113   (2,530 reviews)        $$$      811 Wilshire Blvd  Ste 2100
#
#                        zip  street                       block  \
# 0    Los Angeles, CA 90017     NaN                    Downtown
# 1        Burbank, CA 91505     NaN                         NaN
# 2       Glendale, CA 91203     NaN                         NaN
# 3    Los Angeles, CA 90013     NaN     Arts District, Downtown
# 4         Downey, CA 90241     NaN                         NaN
# ..                     ...     ...                         ...
# 109  Los Angeles, CA 90048     NaN               Beverly Grove
# 110  Los Angeles, CA 90012     NaN                    Downtown
# 111  Los Angeles, CA 90013     NaN     Arts District, Downtown
# 112  Los Angeles, CA 90020     NaN  Wilshire Center, Koreatown
# 113  Los Angeles, CA 90017     NaN                    Downtown
#
#                                                  pages
# 0    <div class="y-css-xdax52"><span class="y-css-w...
# 1    <div class="y-css-xdax52"><span class="y-css-w...
# 2    <div class="y-css-xdax52"><span class="y-css-w...
# 3    <div class="y-css-xdax52"><span class="y-css-w...
# 4    <div class="y-css-xdax52"><span class="y-css-w...
# ..                                                 ...
# 109  <div class="y-css-xdax52"><span class="y-css-w...
# 110  <div class="y-css-xdax52"><span class="y-css-w...
# 111  <div class="y-css-xdax52"><span class="y-css-w...
# 112  <div class="y-css-xdax52"><span class="y-css-w...
# 113  <div class="y-css-xdax52"><span class="y-css-w...
#
# [114 rows x 17 columns]

# %%
restaurant_list.to_csv('nyc_list_location_240701.csv')

# %%
restaurant_info['district'][0]
# Out:
# ['Broadway & 8th Ave',
#  'Theater District, Midtown West',
#  'See all photos from Grace R. for Le Bernardin',
#  'See all photos from Dan B. for Le Bernardin',
#  'See all photos from Kami S. for Le Bernardin',
#  'See all photos from Ross H. for Le Bernardin',
#  'See all photos from Janie D. for Le Bernardin']

# %%
restaurant_info['address'][0]
# Out:
# ['155 W 51st St', 'The Equitable Bldg', 'New York, NY 10019']

# %% [markdown]
# # Review Scrape

# %%
def scrape_restaurant_review(Link, page):
    if page == 0:
      url = f'https://www.yelp.com{Link}&sort_by=date_desc'
    else:
      url = f'https://www.yelp.com{Link}&start={page}&sort_by=date_desc'
    response = requests.get(url)
    content = response.content
    soup = BeautifulSoup(content, 'html.parser')

    if response.status_code == 200:
      review_section = soup.find('div', class_='y-css-1iy1dwt', id="reviews")
      reviews = review_section.find_all('li', class_='y-css-1jp2syp')
      restaurant_data = []
      # restaurant_list = []

      for review in reviews:
        #author information
        author_tag = review.find('a',class_='y-css-12ly5yx')
        author = author_tag.get_text()if author_tag else 'N/A'

        author_locations = review.find('span',class_="y-css-h9c2fl")
        author_location = author_locations.get_text() if author_locations else 'N/A'

        elite_tag = review.find('div', class_='elite-badge__09f24__dyKwK')
        elite_24 = "yes" if elite_tag and elite_tag.find('span', class_='y-css-13vldt4') else "no"

        friends_tag = review.find('div', {'aria-label': 'Friends'})
        friends = friends_tag.find('span', class_='y-css-evk3sl').get_text() if friends_tag else '0'

        reviews_tag = review.find('div', {'aria-label': 'Reviews'})
        reviews = reviews_tag.find('span', class_='y-css-evk3sl').get_text() if reviews_tag else '0'

        photos_tag = review.find('div', {'aria-label': 'Photos'})
        photos = photos_tag.find('span', class_='y-css-evk3sl').get_text() if photos_tag else '0'

        #overall review
        score_tag = review.find('div', {'aria-label': re.compile(r' star rating')})
        score = re.search(r'\d+', score_tag['aria-label']).group() if score_tag else 'N/A'
        date_tag = review.find('span', class_='y-css-wfbtsu')
        date = date_tag.get_text() if date_tag else 'N/A'

        # Features
        features_section = review.find('div',class_='y-css-cluvhg')

        reserved_tag = features_section.find('span', class_='y-css-pw0opj', title="This Yelper made a reservation for this business on Yelp")
        reserved = 'yes' if reserved_tag else 'no'

        pictures_tag = features_section.find('a', class_='y-css-12ly5yx')
        pictures = pictures_tag.get_text() if pictures_tag else 'N/A'

        checked_in_tag = features_section.find('span', class_='y-css-pw0opj')
        checked_in = checked_in_tag.get_text() if checked_in_tag else 'N/A'
        check_in = 'N/A'
        if checked_in == '1 check-in':
          check_in = 'yes'

        #review content
        review_content_tag = review.find('span', class_='raw__09f24__T4Ezm')
        review_content = review_content_tag.get_text(separator='\n') if review_content_tag else 'N/A'

        reaction_section = review.find('div', class_='y-css-o1wrcf')
        reaction_divs = reaction_section.find_all('div',class_='y-css-1b9tgy5')
        helpful = '0'
        thanks = '0'
        love_this = '0'
        oh_no = '0'

        for div in reaction_divs:
          label_tag = div.find('span', class_='y-css-16avcyn')
          count_tag = div.find('span', class_='y-css-q3ifzf')
          if label_tag and count_tag:
              if 'Helpful' in label_tag.get_text():
                helpful = count_tag.get_text()
              elif 'Thanks' in label_tag.get_text():
                thanks = count_tag.get_text()
              elif 'Love this' in label_tag.get_text():
                love_this = count_tag.get_text()
              elif 'Oh no' in label_tag.get_text():
                oh_no = count_tag.get_text()
              else:
                '0'
          else:
            print('no tags found')

        # review reply
        reply_section = review.find('div', class_='y-css-1wjx5j4')
        if reply_section:
          reply_date_tag = reply_section.find('p', class_='y-css-wfbtsu')
          reply_date = reply_date_tag.get_text() if reply_date_tag else 'N/A'
          reply_content_tag = reply_section.find('span', class_="raw__09f24__T4Ezm")
          reply_content = reply_content_tag.get_text(separator='\n') if reply_content_tag else 'N/A'
        else:
          reply_date = 'N/A'
          reply_content = 'N/A'

        restaurant_data.append({
                'Name': author,
                'Profile Location': author_location,
                'Score': score,
                'Date': date,
                'Elite 24': elite_24,
                'Friends': friends,
                'Reviews': reviews,
                'Photos': photos,
                'Comment': review_content,
                'Reply Date': reply_date,
                'Reply Content': reply_content,
                'Helpful': helpful,
                'Thanks': thanks,
                'Love this': love_this,
                'Oh no': oh_no,
                'reserved': reserved,
                'pictures': pictures,
                'checkin': check_in})
        time.sleep(5)
    else:
      print(f"Failed to retrieve the page. Status code: {response.status_code}")
    return pd.DataFrame(restaurant_data)#, pd.DataFrame(restaurant_list)

# %%
info = pd.read_csv('perch1200_1200.csv')

# %%
# info = pd.DataFrame(columns=['Name', 'Profile Location', 'Score', 'Date',
#                                  'Elite 24', 'Friends', 'Reviews', 'Photos', 'reserved', 'pictures', 'checkin',
#                                  'Comment', 'Reply Date','Reply Content', 'Helpful', 'Thanks', 'Love this', 'Oh no'])
Link = '/biz/perch-los-angeles?osq=Restaurants'
# url = f'https://www.yelp.com{Link}&sort_by=date_desc'
# response = requests.get(url)
# content = response.content
# soup = BeautifulSoup(content, 'html.parser')
# pages_section = soup.find('div', class_='pagination__09f24__VRjN4 y-css-jn82xs')
# page_section = pages_section.find('div', class_='y-css-xdax52')
# pages = page_section.find('span', class_='y-css-wfbtsu')
# pages = int(pages.get_text().split(' of ')[-1])
for page in range(1200,10360,10):
  df1 = scrape_restaurant_review(Link, page)
  info = pd.concat([info, df1], ignore_index=True)
# print(f"Total reviews scraped: {len(info)}")
# print(pages)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-dc49bcf3fda8> in <cell line: 13>()
#      12 # pages = int(pages.get_text().split(' of ')[-1])
#      13 for page in range(1200,10360,10):
# ---> 14   df1 = scrape_restaurant_review(Link, page)
#      15   info = pd.concat([info, df1], ignore_index=True)
#      16 # print(f"Total reviews scraped: {len(info)}")
#
# <ipython-input-4-266b72eade0f> in scrape_restaurant_review(Link, page)
#      10     if response.status_code == 200:
#      11       review_section = soup.find('div', class_='y-css-1iy1dwt', id="reviews")
# ---> 12       reviews = review_section.find_all('li', class_='y-css-1jp2syp')
#      13       restaurant_data = []
#      14       # restaurant_list = []
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
info

# %%
info.to_csv(f'perch{page}_{len(info)}.csv', index=False)

# %% [markdown]
# ### Run the function and concatenate them into a single DataFrame

# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
from dateutil import parser
import time

# %%
combined_df = pd.read_csv('945_restaurant_nyc.csv')
# combined_df

# %%
combined_df[109:110]
# Out:
#      Unnamed: 0                    Name  Ranking       Labels  Score  \
# 109         109  DeStefano’s Steakhouse      110  Steakhouses    4.6
#
#              Review                                               Link  \
# 109  (1.1k reviews)  /biz/destefanos-steakhouse-brooklyn?osq=Restau...
#
#     Outdoor seating Available Delivery Available Takeout Available
# 109                     False              False              True

# %%
sample_nyc_100 = combined_df.sample(n=100).reset_index(drop=True)
sample_nyc_100
# Out:
#     Unnamed: 0                                         Name  Ranking  \
# 0           77                                        Rolfs       78
# 1          140   Nick’s Pizza - Forest Hills - Temp. CLOSED      141
# 2          138                    New World Mall Food Court      139
# 3          169                                  Clover Club      170
# 4          208                              Tick Tock Diner      209
# ..         ...                                          ...      ...
# 95         115                                   Soba Totto      116
# 96         199  Tsurutontan Udon Noodle Brasserie - Midtown      200
# 97          78                        EN Japanese Brasserie       79
# 98         226                               Tasty Dumpling      237
# 99          23                                     Freemans       24
#
#                                    Labels  Score          Review  \
# 0                            German, Bars    2.3  (1.4k reviews)
# 1                                   Pizza    4.0   (970 reviews)
# 2                              Food Court    4.1   (953 reviews)
# 3        Lounges, American, Cocktail Bars    4.1   (885 reviews)
# 4                                  Diners    2.6   (754 reviews)
# ..                                    ...    ...             ...
# 95                  Japanese, Salad, Bars    3.8   (952 reviews)
# 96                Japanese, Noodles, Soup    3.7   (764 reviews)
# 97             Japanese, Sushi Bars, Bars    3.8  (1.4k reviews)
# 98                                Chinese    3.7   (642 reviews)
# 99  Breakfast & Brunch, Lounges, American    3.8  (2.2k reviews)
#
#                                                  Link  \
# 0                 /biz/rolfs-new-york?osq=Restaurants
# 1   /biz/nicks-pizza-forest-hills-forest-hills-2?o...
# 2   /biz/new-world-mall-food-court-flushing?osq=Re...
# 3           /biz/clover-club-brooklyn?osq=Restaurants
# 4      /biz/tick-tock-diner-clifton-4?osq=Restaurants
# ..                                                ...
# 95           /biz/soba-totto-new-york?osq=Restaurants
# 96  /biz/tsurutontan-udon-noodle-brasserie-midtown...
# 97  /biz/en-japanese-brasserie-new-york?osq=Restau...
# 98       /biz/tasty-dumpling-new-york?osq=Restaurants
# 99           /biz/freemans-new-york-3?osq=Restaurants
#
#    Outdoor seating Available Delivery Available Takeout Available
# 0                        NaN                NaN               NaN
# 1                       True               True              True
# 2                        NaN                NaN               NaN
# 3                       True               True              True
# 4                       True               True              True
# ..                       ...                ...               ...
# 95                     False               True              True
# 96                       NaN                NaN               NaN
# 97                      True               True              True
# 98                     False               True              True
# 99                      True               True              True
#
# [100 rows x 10 columns]

# %%
info = pd.DataFrame(columns=['Name', 'Profile Location', 'Score', 'Date',
                                 'Elite 24', 'Friends', 'Reviews', 'Photos', 'reserved', 'pictures', 'checkin',
                                 'Comment', 'Helpful', 'Thanks', 'Love this', 'Oh no'])

# %%
restaurant_dataframes = {}
# Loop through each restaurant link
for index, row in unique_df.iloc[2:].iterrows():
    restaurant_name = row["Name"]
    link = row["Link"]
    # review100 = pd.DataFrame()
    for page in range(0,100,10):
        page_info = scrape_restaurant_review(link, page)
        info = pd.concat([info, page_info], ignore_index=True)
    restaurant_dataframes[restaurant_name] = info
    filename = f"{restaurant_name}.csv"
    info.to_csv(filename, index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-f9a85c831329> in <cell line: 3>()
#       6     # review100 = pd.DataFrame()
#       7     for page in range(0,100,10):
# ----> 8         page_info = scrape_restaurant_review(link, page)
#       9         info = pd.concat([info, page_info], ignore_index=True)
#      10     restaurant_dataframes[restaurant_name] = info
#
# <ipython-input-12-266b72eade0f> in scrape_restaurant_review(Link, page)
#      10     if response.status_code == 200:
#      11       review_section = soup.find('div', class_='y-css-1iy1dwt', id="reviews")
# ---> 12       reviews = review_section.find_all('li', class_='y-css-1jp2syp')
#      13       restaurant_data = []
#      14       # restaurant_list = []
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
info
# Out:
#              Name                 Profile Location Score          Date  \
# 0        Julie B.  West Hollywood, Los Angeles, CA     5  Jul 21, 2024
# 1        Alana G.                     San Jose, CA     5  Jul 21, 2024
# 2         Lupe G.                       Perris, CA     5  Jul 21, 2024
# 3         Mrs. S.                    Lancaster, CA     5  Jul 20, 2024
# 4       Lorena P.                           CA, CA     5  Jul 19, 2024
# ..            ...                              ...   ...           ...
# 95  ValleyGirl S.          San Fernando Valley, CA     4  Mar 30, 2024
# 96        Tara L.                  Los Angeles, CA     5  Mar 29, 2024
# 97     Aishani P.                     San Jose, CA     4  Mar 27, 2024
# 98      Karina R.                San Francisco, CA     5  Mar 27, 2024
# 99       Edgar K.                  Los Angeles, CA     1  Mar 26, 2024
#
#    Elite 24 Friends Reviews Photos reserved  pictures checkin  \
# 0        no       3      39      3       no       N/A     N/A
# 1        no     312       6      1       no       N/A     N/A
# 2        no       0       8      3       no       N/A     N/A
# 3        no       0       3      0       no       N/A     N/A
# 4        no       0      30      2       no       N/A     N/A
# ..      ...     ...     ...    ...      ...       ...     ...
# 95       no       0       8     14       no   1 photo     N/A
# 96       no       0      33    135       no   1 photo     yes
# 97       no       0      12      4       no       N/A     N/A
# 98       no      27     141    226       no  2 photos     N/A
# 99       no       0      16      0       no       N/A     N/A
#
#                                               Comment Helpful Thanks  \
# 0   I sent my friends a mail order package to San ...       1      1
# 1   The pastries are delicious and the worker's ar...       0      0
# 2   Quick and great service! Pedro was so kind and...       0      0
# 3   Porto's has delicious food & pastries and the ...       0      0
# 4   From service in front gisel to the nice custom...       0      0
# ..                                                ...     ...    ...
# 95  Portos is for sure a local favorite, and I hav...       1      1
# 96  One of my favorite places to eat! I love the c...       1      1
# 97  Loved the wide selection of baked goods availa...       1      1
# 98  I mean, if you're heading back to NorCal, you ...       1      1
# 99  The server Geovan was rude and not the brighte...       0      1
#
#    Love this Oh no    Reply Date  \
# 0          1     0           N/A
# 1          0     0           N/A
# 2          0     0           N/A
# 3          0     0           N/A
# 4          0     0           N/A
# ..       ...   ...           ...
# 95         1     0           N/A
# 96         1     0           N/A
# 97         1     1           N/A
# 98         2     0           N/A
# 99         0     0  Mar 27, 2024
#
#                                         Reply Content
# 0                                                 N/A
# 1                                                 N/A
# 2                                                 N/A
# 3                                                 N/A
# 4                                                 N/A
# ..                                                ...
# 95                                                N/A
# 96                                                N/A
# 97                                                N/A
# 98                                                N/A
# 99  Hello Edgar, \nThank you for taking the time t...
#
# [100 rows x 18 columns]

# %%
# restaurant_dataframes[restaurant_name] = info
filename = f"{restaurant_name}_70.csv"
info.to_csv(filename, index=False)

# %%
import glob
import os

# List all CSV files
csv_files = glob.glob('*.csv')

# Initialize an empty list to store DataFrames
dataframes = []

# Loop through each CSV file and read it into a DataFrame
for file in csv_files:
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file)

    # Extract the restaurant name from the file name (without extension)
    restaurant_name = os.path.splitext(os.path.basename(file))[0]

    # Add a column with the restaurant name
    df['restaurant_name'] = restaurant_name

    # Ensure the restaurant name is the first column
    df = df[['restaurant_name'] + [col for col in df.columns if col != 'restaurant_name']]

    # Append the DataFrame to the list
    dataframes.append(df)

# Concatenate all DataFrames
merged_df = pd.concat(dataframes, ignore_index=True)

# %%
count = merged_df['restaurant_name'].value_counts()
count
# Out:
# restaurant_name
# Red Hook Lobster Pound       1310
# Buddakan                      100
# The Halal Guys                100
# Amy Ruth’s                    100
# Ippudo NY                     100
# Serendipity 3                 100
# LoveMama                      100
# Di Fara Pizza                 100
# Artichoke Basille’s Pizza     100
# L & B Spumoni Gardens         100
# Name: count, dtype: int64

# %%
red_hook_lobster_pound_100 = combined_df[combined_df['restaurant_name'] == 'Red Hook Lobster Pound'].sample(n=100, random_state=1)

# %%
red_hook_lobster_pound_100.to_csv('red_hook_lobster_pound_100.csv', index=False)

# %%
reviews_df = pd.read_csv('Red Hook Lobster Pound.csv')

# %%
import matplotlib.pyplot as plt

# Converting the Date column to datetime
reviews_df['Date'] = pd.to_datetime(reviews_df['Date'], errors='coerce')

# Filtering out invalid dates
reviews_df = reviews_df.dropna(subset=['Date'])

# Sorting by Date
reviews_df = reviews_df.sort_values('Date')

# Calculating the average score over time
reviews_df['YearMonth'] = reviews_df['Date'].dt.to_period('M')
monthly_avg_score = reviews_df.groupby('YearMonth')['Score'].mean().reset_index()

# Plotting the average score over time
plt.figure(figsize=(14, 6))
plt.plot(monthly_avg_score['YearMonth'].astype(str), monthly_avg_score['Score'], marker='o')
plt.xlabel('Date')
plt.ylabel('Average Score')
plt.title('Average Review Score Over Time')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

plt.show()
